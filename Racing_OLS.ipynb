# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression 
from sklearn.impute import SimpleImputer
import statsmodels.api as sm

# %%
data=pd.read_excel("T:\GOFFOR\Analysis\Ratings Database v20.xls")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\kennyynlee\AppData\Local\Temp\ipykernel_16144\3582506388.py:1: SyntaxWarning: invalid escape sequence '\G'
#   data=pd.read_excel("T:\GOFFOR\Analysis\Ratings Database v20.xls")

# %%
data.tail()
# Out:
#             Date  Race_no Track Course Bend  Distance  Rank Class_no  \
# 31702 2025-10-19       10  TURF     ST  C+3      1600    10        3
# 31703 2025-10-19       10  TURF     ST  C+3      1600    11        3
# 31704 2025-10-19       10  TURF     ST  C+3      1600    12        3
# 31705 2025-10-19       10  TURF     ST  C+3      1600    13        3
# 31706 2025-10-19       10  TURF     ST  C+3      1600    14        3
#
#       Rating_range       Horse_name  ...      Trainer  \
# 31702      080-060     WINNING GOLD  ...     W. Y. So
# 31703      080-060            I CAN  ...     P. C. Ng
# 31704      080-060   MORGAN SUCCESS  ...  D. J. Whyte
# 31705      080-060    AWESOME FLUKE  ...    P. F. Yiu
# 31706      080-060  MASTER TRILLION  ...    F. C. Lor
#
#             Horse Section Time Odds1  Dividend  Strength  Rating Blank  Adj  \
# 31702  24.12 22.60 23.68 23.97  41.0       NaN       NaN  82.416   NaN  0.0
# 31703  24.48 22.52 23.44 24.25  65.0       NaN       NaN  75.750   NaN  0.0
# 31704  24.24 22.72 23.48 24.76   9.2       NaN       NaN  67.583   NaN  0.0
# 31705  24.08 22.40 23.72 25.13  19.0       NaN       NaN  68.375   NaN  0.0
# 31706  25.00 22.68 23.80 24.55  25.0       NaN       NaN  52.458   NaN  0.0
#
#          Base  Position
# 31702  93.666       NaN
# 31703  92.000       NaN
# 31704  91.333       NaN
# 31705  94.000       NaN
# 31706  89.333       NaN
#
# [5 rows x 27 columns]

# %%
X=data[['Weight', 'Draw', 'Margin']]
Y=data['Rank']
imputer=SimpleImputer(strategy='mean')
X_imputed=imputer.fit_transform(X)
X_imputed = pd.DataFrame(X_imputed, columns=X.columns)
X_imputed_with_const = sm.add_constant(X_imputed)

# %%
model = sm.OLS(Y, X_imputed_with_const).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rank   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     9375.
# Date:                Mon, 20 Oct 2025   Prob (F-statistic):               0.00
# Time:                        14:10:12   Log-Likelihood:                -76073.
# No. Observations:               31707   AIC:                         1.522e+05
# Df Residuals:                   31703   BIC:                         1.522e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.7210      0.319     21.076      0.000       6.096       7.346
# Weight        -0.0229      0.003     -9.054      0.000      -0.028      -0.018
# Draw           0.0825      0.004     20.170      0.000       0.075       0.091
# Margin         0.4660      0.003    162.809      0.000       0.460       0.472
# ==============================================================================
# Omnibus:                    10684.543   Durbin-Watson:                   0.794
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           202742.432
# Skew:                          -1.141   Prob(JB):                         0.00
# Kurtosis:                      15.176   Cond. No.                     2.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
